# %%
#diamonds.csv from a source
# !wget https://waf.cs.illinois.edu/discovery/diamonds.csv
# Out:
# --2025-08-17 19:47:17--  https://waf.cs.illinois.edu/discovery/diamonds.csv
# Resolving waf.cs.illinois.edu (waf.cs.illinois.edu)... 18.220.149.166
# Connecting to waf.cs.illinois.edu (waf.cs.illinois.edu)|18.220.149.166|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2502424 (2.4M) [text/csv]
# Saving to: ‘diamonds.csv’
#
# diamonds.csv        100%[===================>]   2.39M  1.81MB/s    in 1.3s
#
# 2025-08-17 19:47:19 (1.81 MB/s) - ‘diamonds.csv’ saved [2502424/2502424]

# %%
#we import pandas so we can work with it (and other things)
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#b) load dataset into a pandas dataframe
df = pd.read_csv('diamonds.csv',index_col=0)

# %%
#c) display the first 7 rows
df.head(7)
# Out:
#              cut color clarity  depth  table  price     x     y     z
# carat
# 0.23       Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 0.21     Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 0.23        Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 0.29     Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 0.31        Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 0.24   Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 0.24   Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47

# %%
#d) display the last 7 rows
df.tail(7)
# Out:
#              cut color clarity  depth  table  price     x     y     z
# carat
# 0.70   Very Good     E     VS2   61.2   59.0   2757  5.69  5.72  3.49
# 0.72     Premium     D     SI1   62.7   59.0   2757  5.69  5.73  3.58
# 0.72       Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 0.72        Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 0.70   Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 0.86     Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 0.75       Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64

# %%
#e) use the df method describe to calc. desc. stats for carat, depth, table, price, x , y, and z
df.describe()
# Out:
#               depth         table         price             x             y  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean      61.749405     57.457184   3932.799722      5.731157      5.734526
# std        1.432621      2.234491   3989.439738      1.121761      1.142135
# min       43.000000     43.000000    326.000000      0.000000      0.000000
# 25%       61.000000     56.000000    950.000000      4.710000      4.720000
# 50%       61.800000     57.000000   2401.000000      5.700000      5.710000
# 75%       62.500000     59.000000   5324.250000      6.540000      6.540000
# max       79.000000     95.000000  18823.000000     10.740000     58.900000
#
#                   z
# count  53940.000000
# mean       3.538734
# std        0.705699
# min        0.000000
# 25%        2.910000
# 50%        3.530000
# 75%        4.040000
# max       31.800000

# %%
#f) use the series method descripte to calc. desc. stats for cut, color, and clarity
print(df['cut'].describe())
print(df['color'].describe())
print(df['clarity'].describe())
# Out:
# count     53940
# unique        5
# top       Ideal
# freq      21551
# Name: cut, dtype: object
# count     53940
# unique        7
# top           G
# freq      11292
# Name: color, dtype: object
# count     53940
# unique        8
# top         SI1
# freq      13065
# Name: clarity, dtype: object

# %%
#g) what are the unique category values?

print(df['cut'].unique())
print(df['color'].unique())
print(df['clarity'].unique())
# Out:
# ['Ideal' 'Premium' 'Good' 'Very Good' 'Fair']
# ['E' 'I' 'J' 'H' 'F' 'G' 'D']
# ['SI2' 'SI1' 'VS1' 'VS2' 'VVS2' 'VVS1' 'I1' 'IF']

# %%
#h) enable matplotlib support, then call the hist method of the dataframe
# %matplotlib inline
dHist = df.hist()
